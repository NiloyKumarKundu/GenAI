# %% [markdown]
# <a href="https://colab.research.google.com/github/NiloyKumarKundu/GenAI/blob/main/Gemini_using_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
from google.colab import userdata
import os

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
import google.generativeai as genai

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# %%
for models in genai.list_models():
  print(models)
# Out:
# Model(name='models/chat-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 Chat (Legacy)',
#       description='A legacy text-only model optimized for chat conversations',
#       input_token_limit=4096,
#       output_token_limit=1024,
#       supported_generation_methods=['generateMessage', 'countMessageTokens'],
#       temperature=0.25,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/text-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 (Legacy)',
#       description='A legacy model that understands text and generates text as an output',
#       input_token_limit=8196,
#       output_token_limit=1024,
#       supported_generation_methods=['generateText', 'countTextTokens', 'createTunedTextModel'],
#       temperature=0.7,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/embedding-gecko-001',
#       base_model_id='',
# ...

# %%
for models in genai.list_models():
  if 'generateContent' in models.supported_generation_methods:
    print(models)
# Out:
# Model(name='models/gemini-1.0-pro-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro Latest',
#       description=('The best model for scaling across a wide range of tasks. This is the latest '
#                    'model.'),
#       input_token_limit=30720,
#       output_token_limit=2048,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.9,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=None)
# Model(name='models/gemini-1.0-pro',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro',
#       description='The best model for scaling across a wide range of tasks',
#       input_token_limit=30720,
#       output_token_limit=2048,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.9,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=None)
# Model(name='models/gemini-pro',
# ...

# %% [markdown]
# ## Generate text from inputs

# %%
model = genai.GenerativeModel("gemini-pro")

# %%
# %%time
response = model.generate_content("What is the meaning of life?")
# Out:
# CPU times: user 64.4 ms, sys: 6.74 ms, total: 71.2 ms
# Wall time: 7.17 s

# %%
response.text
# Out:
# "The meaning of life is a deeply personal and subjective question, and there is no single, universally agreed-upon answer. However, some common themes that emerge in discussions about the meaning of life include finding purpose, fulfilling one's potential, and making a positive contribution to the world.\n\nOne way to think about the meaning of life is to consider what you value most and what brings you joy and fulfillment. What are your passions, your interests, and your goals? What do you want to accomplish in your life? Once you have a better understanding of what is important to you, you can start to make choices that are aligned with your values and goals.\n\nAnother way to think about the meaning of life is to consider your role in the world. How do you want to make a difference? What is your unique contribution to society? It doesn't matter how big or small your impact is, every act of kindness and compassion makes a difference.\n\nUltimately, the meaning of life is something 
# ...

# %%
from IPython.display import Markdown
Markdown(response.text)
# Out:
# The meaning of life is a deeply personal and subjective question, and there is no single, universally agreed-upon answer. However, some common themes that emerge in discussions about the meaning of life include finding purpose, fulfilling one's potential, and making a positive contribution to the world.
#
# One way to think about the meaning of life is to consider what you value most and what brings you joy and fulfillment. What are your passions, your interests, and your goals? What do you want to accomplish in your life? Once you have a better understanding of what is important to you, you can start to make choices that are aligned with your values and goals.
#
# Another way to think about the meaning of life is to consider your role in the world. How do you want to make a difference? What is your unique contribution to society? It doesn't matter how big or small your impact is, every act of kindness and compassion makes a difference.
#
# ...

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
response.parts
# Out:
# [text: "The meaning of life is a deeply personal and subjective question, and there is no single, universally agreed-upon answer. However, some common themes that emerge in discussions about the meaning of life include finding purpose, fulfilling one\'s potential, and making a positive contribution to the world.\n\nOne way to think about the meaning of life is to consider what you value most and what brings you joy and fulfillment. What are your passions, your interests, and your goals? What do you want to accomplish in your life? Once you have a better understanding of what is important to you, you can start to make choices that are aligned with your values and goals.\n\nAnother way to think about the meaning of life is to consider your role in the world. How do you want to make a difference? What is your unique contribution to society? It doesn\'t matter how big or small your impact is, every act of kindness and compassion makes a difference.\n\nUltimately, the meaning of life is s
# ...

# %%
response.prompt_feedback

# %%
model2 = genai.GenerativeModel("gemini-1.5-flash")

# %%
response2 = model2.generate_content("What is the meaning of life?")

# %%
Markdown(response2.text)
# Out:
# The meaning of life is a question that has been pondered by philosophers and theologians for centuries, and there is no one definitive answer.
#
# Here are some different perspectives:
#
# **Philosophical Perspectives:**
#
# * **Nihilism:**  Life has no inherent meaning or purpose. We create our own meaning through our actions and experiences.
# * **Existentialism:** We are free to choose our own meaning and values.  We are responsible for creating our own lives.
# * **Absurdism:** The universe is indifferent to us, and life is inherently meaningless. However, we can still find joy and fulfillment in the face of this absurdity.
# * **Hedonism:** The pursuit of pleasure and happiness is the ultimate goal in life.
# * **Utilitarianism:** The goal of life is to maximize happiness for the greatest number of people.
#
# **Religious Perspectives:**
#
# * **Theism:** Life has a purpose given by a higher power. The meaning of life is to serve God or fulfill a divine plan.
# ...

# %%
response2.candidates
# Out:
# [content {
#   parts {
# ...

# %%
response2.parts
# Out:
# [text: "The meaning of life is a question that has been pondered by philosophers and theologians for centuries, and there is no one definitive answer. \n\nHere are some different perspectives:\n\n**Philosophical Perspectives:**\n\n* **Nihilism:**  Life has no inherent meaning or purpose. We create our own meaning through our actions and experiences.\n* **Existentialism:** We are free to choose our own meaning and values.  We are responsible for creating our own lives.\n* **Absurdism:** The universe is indifferent to us, and life is inherently meaningless. However, we can still find joy and fulfillment in the face of this absurdity.\n* **Hedonism:** The pursuit of pleasure and happiness is the ultimate goal in life.\n* **Utilitarianism:** The goal of life is to maximize happiness for the greatest number of people.\n\n**Religious Perspectives:**\n\n* **Theism:** Life has a purpose given by a higher power. The meaning of life is to serve God or fulfill a divine plan.\n* **Buddhism:** Th
# ...

# %%
vision_model = model2

# %%
import PIL.Image

img_path = "/content/image (99).JPG"
img = PIL.Image.open(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
response = vision_model.generate_content(["This is an image of tomato leaf disease. Tell me what you see in this leaf?", img])

# %%
Markdown(response.text)
# Out:
# The leaf has brown spots and a browning margin. The brown spots could indicate a fungal disease, such as Septoria leaf spot or early blight. The browning margin could be caused by environmental factors, such as stress or nutrient deficiency, but it could also be a symptom of a disease. To determine the specific cause of the leaf damage, a plant pathologist would need to examine the leaf in more detail.

# %%
img_path = "/content/image (980).JPG"
img = PIL.Image.open(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
response = vision_model.generate_content(["This is an image of tomato leaf disease. Tell me what you see in this leaf?", img])

# %%
Markdown(response.text)
# Out:
# The tomato leaf has several brown spots and some areas of yellowing. The edges of the leaf are also browning and curling. This could be a sign of several diseases, including Septoria leaf spot, early blight, or bacterial spot.  It would be helpful to see the underside of the leaf to get a better idea of the disease.

# %%
img_path = "/content/image (99).JPG"
img = PIL.Image.open(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
response = vision_model.generate_content(["This is an image of tomato leaf disease. Tell me what you see in this leaf?", img])
Markdown(response.text)
# Out:
# The tomato leaf has brown spots on the edges. This could be a sign of several diseases, including bacterial spot, septoria leaf spot, or early blight. It is difficult to diagnose the specific disease without more information.

# %%
img_path = "/content/image (99).JPG"
img = PIL.Image.open(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
response = vision_model.generate_content(["This is an image of tomato leaf disease. Tell me what you see in this leaf?", img])
Markdown(response.text)
# Out:
# The tomato leaf shows signs of **Early Blight**. It is characterized by **brown, dead spots**, which are usually **irregularly shaped** and have a **target-like appearance**. The **spots can be surrounded by a yellow halo**. These symptoms can be seen on the leaf in the image.
